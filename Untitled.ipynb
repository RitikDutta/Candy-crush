# %%
import os
import numpy as np
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
cc_img = mpimg.imread("cc.jpg")
plt.imshow(cc_img)

# %%
from PIL import Image

coords = (161, 166, 706, 1050)
image_obj = Image.open("cc.jpg")
cropped_image = image_obj.crop(coords)
cropped_image = cropped_image.resize(30, 20)
plt.imshow(cropped_image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ce2c46644f3f> in <module>()
#       4 image_obj = Image.open("cc.jpg")
#       5 cropped_image = image_obj.crop(coords)
# ----> 6 cropped_image = cropped_image.resize(30, 20)
#       7 plt.imshow(cropped_image)
#
# D:\DevelopersApplications\Python\lib\site-packages\PIL\Image.py in resize(self, size, resample)
#    1693                 NEAREST, BILINEAR, BICUBIC, LANCZOS, BOX, HAMMING,
#    1694         ):
# -> 1695             raise ValueError("unknown resampling filter")
#    1696
#    1697         self.load()
#
# ValueError: unknown resampling filter

# %%
basewidth = 300
img = Image.open('cc.jpg')
wpercent = (basewidth/float(img.size[0]))
hsize = int((float(img.size[1])*float(wpercent)))
img = img.resize((basewidth,hsize), Image.ANTIALIAS)
img.save('sompic.jpg')

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x1B7B2CF8C50>

# %%
k=60
area = (30+k, 10, 85+k, 60)
purple = img.crop(box=(30+k, 10, 85+k, 60))

orange = img.crop(box=(30+k*2, 10, 85+k*2, 60))
orange

green = img.crop(box=(30+k*3, 10, 85+k*3, 60))
green

blue = img.crop(box=(30+k*5, 10, 85+k*5, 60))
blue

red = img.crop(box=(30+k*6, 10, 85+k*6, 60))
red
# Out:
# <PIL.Image.Image image mode=RGB size=55x50 at 0x1B7B59D4BE0>

# %%
plt.imshow(purple)

# %%
plt.imshow(orange)

# %%
plt.imshow(green)

# %%
plt.imshow(blue)

# %%
plt.imshow(red)

# %%
X = [purple, orange, green, blue, red]
X[0]
y=[1, 2, 3, 4, 5]

# %%
X_l = np.array(im)

# %%
X_train = np.array(X[0]), np.array(X[1]), np.array(X[2]), np.array(X[3]), np.array(X[4])

# %%
from sklearn.linear_model import SGDClassifier
y=1
sgd_clf = SGDClassifier(max_iter=5)
sgd_clf.fit(X_train[0], y[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-251-0b2d1f28c95a> in <module>()
#       2 y=1
#       3 sgd_clf = SGDClassifier(max_iter=5)
# ----> 4 sgd_clf.fit(X_train[0], y[0])
#
# TypeError: 'int' object is not subscriptable

# %%
X_train
# Out:
# (array([[[ 46,  72,  95],
#          [ 51,  77, 102],
#          [ 57,  83, 106],
#          ...,
#          [ 50,  84,  96],
#          [ 50,  84,  96],
#          [ 54,  84, 108]],
#
#         [[ 42,  70,  94],
#          [ 48,  76,  98],
#          [ 55,  83, 105],
#          ...,
#          [ 47,  81,  93],
#          [ 47,  81,  93],
#          [ 51,  82, 103]],
#
#         [[ 42,  70,  92],
#          [ 48,  76,  98],
#          [ 54,  82, 103],
#          ...,
#          [ 51,  84,  99],
#          [ 51,  84,  99],
#          [ 53,  84, 104]],
#
#         ...,
#
#         [[ 88,  95, 114],
#          [ 93, 102, 119],
#          [ 96, 107, 125],
#          ...,
#          [102, 109, 135],
#          [102, 107, 136],
#          [ 98, 110, 134]],
#
#         [[ 88,  96, 115],
#          [ 95, 104, 121],
#          [ 98, 109, 127],
#          ...,
#          [105, 113, 136],
#          [105, 112, 138],
#          [ 99, 111, 135]],
#
#         [[ 90,  98, 117],
# ...

# %%
from sklearn import svm
clf = svm.SVC()
ss = np.array(blue)
clf.fit(ss, 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-256-4dc4c44e6c57> in <module>()
#       2 clf = svm.SVC()
#       3 ss = np.array(blue)
# ----> 4 clf.fit(ss, 1)
#
# D:\DevelopersApplications\Python\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# D:\DevelopersApplications\Python\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
ss = ss.transpose(2, 0, 1).reshape(3, -1)

# %%
clf.fit(ss, 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-266-ab3eb45be8be> in <module>()
# ----> 1 clf.fit(ss, 2)
#
# D:\DevelopersApplications\Python\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# D:\DevelopersApplications\Python\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     576                         dtype=None)
#     577     else:
# --> 578         y = column_or_1d(y, warn=True)
#     579         _assert_all_finite(y)
# ...

# %%
X_train_new = [X_train[0].transpose(2, 0, 1).reshape(3, -1), X_train[1].transpose(2, 0, 1).reshape(3, -1),
              X_train[2].transpose(2, 0, 1).reshape(3, -1), X_train[3].transpose(2, 0, 1).reshape(3, -1),
              X_train[4].transpose(2, 0, 1).reshape(3, -1),
              ]

# %%
aa = [2],[2]
aa
# Out:
# ([2], [2])

# %%
X_train_new
# Out:
# [array([[ 46,  51,  57, ..., 100, 100,  95],
#         [ 72,  77,  83, ..., 111, 111, 107],
#         [ 95, 102, 106, ..., 131, 133, 131]], dtype=uint8),
#  array([[ 53,  53,  52, ..., 105, 106, 109],
#         [ 83,  83,  82, ..., 121, 119, 117],
#         [107, 107, 106, ..., 137, 136, 136]], dtype=uint8),
#  array([[ 71,  68,  65, ..., 103, 103, 109],
#         [ 98,  95,  94, ..., 120, 120, 123],
#         [115, 114, 112, ..., 127, 128, 134]], dtype=uint8),
#  array([[ 44,  44,  45, ..., 101, 101, 102],
#         [ 71,  71,  72, ..., 118, 118, 117],
#         [ 92,  92,  93, ..., 125, 125, 138]], dtype=uint8),
#  array([[ 48,  49,  48, ..., 106, 107, 108],
#         [ 80,  81,  80, ..., 111, 112, 113],
#         [ 91,  92,  91, ..., 131, 131, 132]], dtype=uint8)]

# %%
clf.fit(X_train_new,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-288-a227f5f4d8b6> in <module>()
# ----> 1 clf.fit(X_train_new,y)
#
# D:\DevelopersApplications\Python\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# D:\DevelopersApplications\Python\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...
